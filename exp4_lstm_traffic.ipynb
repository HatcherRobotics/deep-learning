# %%
import os
import numpy as np
import pandas as pd
import torch
from torch import nn
import torch.utils.data as data

# %%
# 定义dataset
class my_Dataset(data.Dataset):#继承？
    def __init__(self, features, labels):
        self.X = features
        self.y = labels

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return self.X.shape[0]

# %%
class TrafficDataset:
    def __init__(self, sensor_num=10, target=0):
        # 选取适当的检测器用作序列数据
        self.raw_data = np.load('./traffic-flow/traffic.npz')['data']
        self.sensor_num = sensor_num
        self.target = target
        # 数据标准化
        self.min = self.raw_data.min()
        self.max = self.raw_data.max()
        self.data = (self.raw_data - self.min) / (self.max - self.min)

    def denormalize(self, x):
        return x * (self.max - self.min) + self.min

    def construct_set(self, train_por=0.6,val_por=0.2,test_por=0.2, window_size=12,label=0):
        train_x = []
        train_y = []
        val_x = []
        val_y = []
        test_x = []
        test_y = []
        len_train = int(self.data.shape[0] * train_por)
        len_val = int(self.data.shape[0] * val_por)
        len_test = int(self.data.shape[0] * test_por)
        train_seqs = self.data[:len_train]
        val_seqs = self.data[len_train:len_val+len_train]
        test_seqs = self.data[len_train+len_val:len_val+len_train+len_test]

        for i in range(train_seqs.shape[0] - window_size):
            train_x.append(train_seqs[i:i+window_size, self.sensor_num, :].squeeze())
            train_y.append(train_seqs[i+window_size, self.sensor_num, self.target].squeeze())

        for i in range(val_seqs.shape[0] - window_size):
            val_x.append(val_seqs[i:i+window_size, self.sensor_num, :].squeeze())
            val_y.append(val_seqs[i+window_size, self.sensor_num, self.target].squeeze())

        for i in range(test_seqs.shape[0] - window_size):
            test_x.append(test_seqs[i:i+window_size, self.sensor_num, :].squeeze())
            test_y.append(test_seqs[i+window_size, self.sensor_num, self.target].squeeze())
        
        train_set = my_Dataset(torch.Tensor(train_x), torch.Tensor(train_y))
        val_set = my_Dataset(torch.Tensor(val_x), torch.Tensor(val_y))
        test_set = my_Dataset(torch.Tensor(test_x), torch.Tensor(test_y))
        return train_set, val_set, test_set

# %%
TrafficData = TrafficDataset()
train_set, val_set, test_set = TrafficData.construct_set()
batch_size = 64
train_loader = data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4, drop_last=True)
val_loader = data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
test_loader = data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
# Out:
# <ipython-input-3-72cc8f8dabf6>:41: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   train_set = my_Dataset(torch.Tensor(train_x), torch.Tensor(train_y))

# %%
from utils import *
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size = train_set.X.shape[-1]
hidden_size = 64
output_size = 1
seq_len = 12
lr = 0.0001
epochs = 80
loss_func = nn.MSELoss()
# Out:
# /home/hatcher/anaconda3/lib/python3.8/site-packages/torch/cuda/__init__.py:80: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
lstm = nn.LSTM(input_size=input_size,hidden_size=hidden_size,num_layers=1,batch_first=True).to(device)
out_linear = nn.Sequential(nn.Linear(hidden_size, 1),nn.LeakyReLU()).to(device)
optimizer = torch.optim.Adam(list(lstm.parameters()) + list(out_linear.parameters()), lr)

# %%
train_loss_lst, val_loss_lst, \
    train_score_lst, val_score_lst, stop_epoch = train(lstm, train_loader, val_loader, test_loader,
                                                       loss_func, TrafficData.denormalize, optimizer, epochs,
                                                       early_stop=20, device=device, output_model=out_linear)
# Out:
# *** epoch1, train loss 0.0908, train rmse 318.7410, val loss 0.0133, val rmse 119.468608, time use 1.075s
# *** epoch2, train loss 0.0114, train rmse 121.9628, val loss 0.0082, val rmse 93.342184, time use 1.022s
# *** epoch3, train loss 0.0057, train rmse 85.8213, val loss 0.0040, val rmse 65.082982, time use 0.957s
# *** epoch4, train loss 0.0035, train rmse 67.4574, val loss 0.0035, val rmse 59.179718, time use 0.919s
# *** epoch5, train loss 0.0034, train rmse 66.0676, val loss 0.0034, val rmse 58.496806, time use 0.904s
# *** epoch6, train loss 0.0033, train rmse 64.9020, val loss 0.0034, val rmse 59.260606, time use 0.938s
# *** epoch7, train loss 0.0032, train rmse 64.3433, val loss 0.0033, val rmse 58.135248, time use 0.913s
# *** epoch8, train loss 0.0032, train rmse 63.5296, val loss 0.0032, val rmse 56.370635, time use 0.894s
# *** epoch9, train loss 0.0031, train rmse 62.8216, val loss 0.0031, val rmse 55.155157, time use 0.955s
# *** epoch10, train loss 0.0030, train rmse 61.5330, val loss 0.0030, val rmse 54.491289, time use 0.881s
# *** epoch11, train loss 0.0029, train rmse 60.7738, val loss 0.0029, val rmse 52.626364, time use 0.919s
# *** epoch12, train loss 0.0027, train rmse 59.1613, val loss 0.0028, val rmse 51.426938, time use 0.895s
# *** epoch13, train loss 0.0026, train rmse 58.1079, val loss 0.0027, val rmse 49.981548, time use 0.937s
# *** epoch14, train loss 0.0025, train rmse 56.1265, val loss 0.0026, val rmse 48.565206, time use 0.923s
# *** epoch15, train loss 0.0023, train rmse 54.3395, val loss 0.0025, val rmse 46.967998, time use 0.969s
# *** epoch16, train loss 0.0022, train rmse 53.3807, val loss 0.0024, val rmse 45.738975, time use 0.921s
# *** epoch17, train loss 0.0022, train rmse 52.8837, val loss 0.0024, val rmse 45.784752, time use 0.908s
# *** epoch18, train loss 0.0022, train rmse 52.1524, val loss 0.0024, val rmse 45.499804, time use 0.973s
# *** epoch19, train loss 0.0021, train rmse 51.7636, val loss 0.0023, val rmse 44.437539, time use 1.010s
# *** epoch20, train loss 0.0021, train rmse 51.3958, val loss 0.0023, val rmse 44.849138, time use 0.943s
# *** epoch21, train loss 0.0021, train rmse 51.2013, val loss 0.0023, val rmse 43.514407, time use 0.865s
# *** epoch22, train loss 0.0021, train rmse 50.8862, val loss 0.0022, val rmse 43.296651, time use 0.959s
# *** epoch23, train loss 0.0020, train rmse 50.3720, val loss 0.0022, val rmse 43.169577, time use 1.129s
# *** epoch24, train loss 0.0020, train rmse 50.1732, val loss 0.0022, val rmse 42.911249, time use 0.915s
# *** epoch25, train loss 0.0020, train rmse 50.0680, val loss 0.0022, val rmse 43.057704, time use 0.895s
# *** epoch26, train loss 0.0020, train rmse 49.5498, val loss 0.0021, val rmse 42.212810, time use 1.162s
# *** epoch27, train loss 0.0019, train rmse 49.3999, val loss 0.0021, val rmse 42.050985, time use 1.073s
# *** epoch28, train loss 0.0019, train rmse 49.0820, val loss 0.0021, val rmse 41.551334, time use 1.122s
# *** epoch29, train loss 0.0019, train rmse 48.9879, val loss 0.0022, val rmse 44.041909, time use 0.964s
# *** epoch30, train loss 0.0019, train rmse 48.5482, val loss 0.0020, val rmse 41.096111, time use 0.925s
# *** epoch31, train loss 0.0019, train rmse 48.9317, val loss 0.0020, val rmse 40.805029, time use 1.129s
# *** epoch32, train loss 0.0018, train rmse 48.1732, val loss 0.0020, val rmse 40.840288, time use 1.197s
# *** epoch33, train loss 0.0018, train rmse 47.9088, val loss 0.0020, val rmse 42.068065, time use 0.934s
# *** epoch34, train loss 0.0018, train rmse 47.6678, val loss 0.0020, val rmse 41.384462, time use 1.199s
# *** epoch35, train loss 0.0018, train rmse 47.4099, val loss 0.0020, val rmse 41.546149, time use 0.914s
# *** epoch36, train loss 0.0018, train rmse 47.5833, val loss 0.0019, val rmse 39.868415, time use 1.167s
# *** epoch37, train loss 0.0018, train rmse 47.2894, val loss 0.0020, val rmse 40.548607, time use 0.898s
# *** epoch38, train loss 0.0018, train rmse 47.1642, val loss 0.0020, val rmse 40.842891, time use 0.938s
# *** epoch39, train loss 0.0017, train rmse 46.7563, val loss 0.0019, val rmse 39.363619, time use 1.005s
# *** epoch40, train loss 0.0017, train rmse 46.6797, val loss 0.0019, val rmse 39.268190, time use 0.971s
# *** epoch41, train loss 0.0017, train rmse 46.7569, val loss 0.0019, val rmse 39.091037, time use 1.009s
# *** epoch42, train loss 0.0017, train rmse 46.6952, val loss 0.0019, val rmse 39.731289, time use 0.918s
# *** epoch43, train loss 0.0017, train rmse 46.4532, val loss 0.0019, val rmse 40.153389, time use 1.128s
# *** epoch44, train loss 0.0017, train rmse 46.3678, val loss 0.0019, val rmse 39.819313, time use 1.086s
# *** epoch45, train loss 0.0017, train rmse 46.3297, val loss 0.0019, val rmse 38.819953, time use 1.130s
# *** epoch46, train loss 0.0017, train rmse 46.2110, val loss 0.0019, val rmse 39.856789, time use 1.132s
# *** epoch47, train loss 0.0017, train rmse 46.1509, val loss 0.0019, val rmse 39.221973, time use 0.952s
# *** epoch48, train loss 0.0017, train rmse 46.0516, val loss 0.0018, val rmse 38.651272, time use 0.929s
# *** epoch49, train loss 0.0017, train rmse 46.6154, val loss 0.0018, val rmse 38.703207, time use 1.129s
# *** epoch50, train loss 0.0017, train rmse 46.0869, val loss 0.0018, val rmse 39.078831, time use 0.893s
# *** epoch51, train loss 0.0017, train rmse 46.2294, val loss 0.0018, val rmse 38.979445, time use 1.094s
# *** epoch52, train loss 0.0017, train rmse 46.0320, val loss 0.0019, val rmse 39.793331, time use 0.914s
# *** epoch53, train loss 0.0017, train rmse 45.9972, val loss 0.0018, val rmse 38.405370, time use 0.996s
# *** epoch54, train loss 0.0017, train rmse 45.5945, val loss 0.0018, val rmse 38.174718, time use 0.954s
# *** epoch55, train loss 0.0017, train rmse 45.6870, val loss 0.0020, val rmse 41.241933, time use 0.980s
# *** epoch56, train loss 0.0017, train rmse 45.7410, val loss 0.0018, val rmse 38.283021, time use 0.952s
# *** epoch57, train loss 0.0017, train rmse 45.8281, val loss 0.0018, val rmse 38.981833, time use 0.937s
# *** epoch58, train loss 0.0016, train rmse 45.6500, val loss 0.0018, val rmse 38.404974, time use 0.988s
# *** epoch59, train loss 0.0016, train rmse 45.6569, val loss 0.0019, val rmse 40.358202, time use 0.936s
# *** epoch60, train loss 0.0016, train rmse 45.6622, val loss 0.0018, val rmse 39.249170, time use 1.111s
# *** epoch61, train loss 0.0017, train rmse 45.8143, val loss 0.0018, val rmse 38.087726, time use 0.894s
# *** epoch62, train loss 0.0016, train rmse 45.6730, val loss 0.0018, val rmse 38.004886, time use 0.898s
# *** epoch63, train loss 0.0016, train rmse 45.5335, val loss 0.0018, val rmse 39.133714, time use 0.848s
# *** epoch64, train loss 0.0016, train rmse 45.3841, val loss 0.0018, val rmse 38.051852, time use 1.018s
# *** epoch65, train loss 0.0016, train rmse 45.5421, val loss 0.0018, val rmse 37.697978, time use 0.910s
# *** epoch66, train loss 0.0016, train rmse 45.2210, val loss 0.0018, val rmse 37.653146, time use 0.985s
# *** epoch67, train loss 0.0016, train rmse 45.2546, val loss 0.0018, val rmse 37.670437, time use 0.906s
# *** epoch68, train loss 0.0016, train rmse 45.4131, val loss 0.0018, val rmse 37.992041, time use 1.029s
# *** epoch69, train loss 0.0016, train rmse 45.4755, val loss 0.0018, val rmse 37.780060, time use 0.921s
# *** epoch70, train loss 0.0016, train rmse 45.3706, val loss 0.0017, val rmse 37.521817, time use 1.076s
# *** epoch71, train loss 0.0016, train rmse 45.3102, val loss 0.0017, val rmse 37.466740, time use 0.922s
# *** epoch72, train loss 0.0016, train rmse 45.3859, val loss 0.0017, val rmse 37.665735, time use 0.933s
# *** epoch73, train loss 0.0016, train rmse 45.1877, val loss 0.0017, val rmse 37.805768, time use 1.155s
# *** epoch74, train loss 0.0016, train rmse 45.3379, val loss 0.0018, val rmse 37.805219, time use 0.883s
# *** epoch75, train loss 0.0016, train rmse 45.2053, val loss 0.0018, val rmse 39.492789, time use 1.190s
# *** epoch76, train loss 0.0016, train rmse 45.3569, val loss 0.0018, val rmse 38.902172, time use 0.957s
# *** epoch77, train loss 0.0016, train rmse 45.2513, val loss 0.0017, val rmse 37.819470, time use 1.288s
# *** epoch78, train loss 0.0016, train rmse 45.2858, val loss 0.0017, val rmse 37.730235, time use 0.950s
# *** epoch79, train loss 0.0016, train rmse 45.0618, val loss 0.0018, val rmse 38.140345, time use 1.029s
# *** epoch80, train loss 0.0016, train rmse 44.9957, val loss 0.0017, val rmse 37.307886, time use 1.141s
#
# ****************************************
# Final result:
# Get best validation rmse 37.3079 at epoch 79
# Total time 79.32s
#
# Test result:
# Test RMSE: 36.16846026310126    Test MAE: 25.340703157945114    Test MAPE: 7.908599630675533

# %%
visualize(stop_epoch, train_loss_lst, val_loss_lst, y_label='Loss')
plot_metric(train_score_lst)
