# %%
import os
import numpy as np
import pandas as pd
import torch
from torch import nn
import torch.utils.data as data

# %%
# 定义dataset
class my_Dataset(data.Dataset):#继承？
    def __init__(self, features, labels):
        self.X = features
        self.y = labels

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return self.X.shape[0]

# %%
class TrafficDataset:
    def __init__(self, sensor_num=10, target=0):
        # 选取适当的检测器用作序列数据
        self.raw_data = np.load('./traffic-flow/traffic.npz')['data']
        self.sensor_num = sensor_num
        self.target = target
        # 数据标准化
        self.min = self.raw_data.min()
        self.max = self.raw_data.max()
        self.data = (self.raw_data - self.min) / (self.max - self.min)

    def denormalize(self, x):
        return x * (self.max - self.min) + self.min

    def construct_set(self, train_por=0.6,val_por=0.2,test_por=0.2, window_size=12,label=0):
        train_x = []
        train_y = []
        val_x = []
        val_y = []
        test_x = []
        test_y = []
        len_train = int(self.data.shape[0] * train_por)
        len_val = int(self.data.shape[0] * val_por)
        len_test = int(self.data.shape[0] * test_por)
        train_seqs = self.data[:len_train]
        val_seqs = self.data[len_train:len_val+len_train]
        test_seqs = self.data[len_train+len_val:len_val+len_train+len_test]

        for i in range(train_seqs.shape[0] - window_size):
            train_x.append(train_seqs[i:i+window_size, self.sensor_num, :].squeeze())
            train_y.append(train_seqs[i+window_size, self.sensor_num, self.target].squeeze())

        for i in range(val_seqs.shape[0] - window_size):
            val_x.append(val_seqs[i:i+window_size, self.sensor_num, :].squeeze())
            val_y.append(val_seqs[i+window_size, self.sensor_num, self.target].squeeze())

        for i in range(test_seqs.shape[0] - window_size):
            test_x.append(test_seqs[i:i+window_size, self.sensor_num, :].squeeze())
            test_y.append(test_seqs[i+window_size, self.sensor_num, self.target].squeeze())
        
        train_set = my_Dataset(torch.Tensor(train_x), torch.Tensor(train_y))
        val_set = my_Dataset(torch.Tensor(val_x), torch.Tensor(val_y))
        test_set = my_Dataset(torch.Tensor(test_x), torch.Tensor(test_y))
        return train_set, val_set, test_set

# %%
TrafficData = TrafficDataset()
train_set, val_set, test_set = TrafficData.construct_set()
batch_size = 64
train_loader = data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4, drop_last=True)
val_loader = data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
test_loader = data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
# Out:
# <ipython-input-3-72cc8f8dabf6>:41: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   train_set = my_Dataset(torch.Tensor(train_x), torch.Tensor(train_y))

# %%
from utils import *
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size = train_set.X.shape[-1]
hidden_size = 64
output_size = 1
seq_len = 12
lr = 0.0001
epochs = 80
loss_func = nn.MSELoss()

# %%
lstm = nn.LSTM(input_size=input_size,hidden_size=hidden_size,num_layers=1,batch_first=True).to(device)
out_linear = nn.Sequential(nn.Linear(hidden_size, 1),nn.LeakyReLU()).to(device)
optimizer = torch.optim.Adam(list(lstm.parameters()) + list(out_linear.parameters()), lr)

# %%
train_loss_lst, val_loss_lst, \
    train_score_lst, val_score_lst, stop_epoch = train(lstm, train_loader, val_loader, test_loader,
                                                       loss_func, TrafficData.denormalize, optimizer, epochs,
                                                       early_stop=20, device=device, output_model=out_linear)
# Out:
# *** epoch1, train loss 0.0499, train rmse 244.8559, val loss 0.0181, val rmse 139.970546, time use 0.425s
# *** epoch2, train loss 0.0160, train rmse 144.3124, val loss 0.0110, val rmse 108.102995, time use 0.407s
# *** epoch3, train loss 0.0067, train rmse 92.2684, val loss 0.0043, val rmse 66.328987, time use 0.408s
# *** epoch4, train loss 0.0040, train rmse 71.9266, val loss 0.0040, val rmse 64.178257, time use 0.383s
# *** epoch5, train loss 0.0039, train rmse 70.3821, val loss 0.0038, val rmse 62.024550, time use 0.385s
# *** epoch6, train loss 0.0037, train rmse 69.1916, val loss 0.0037, val rmse 61.724607, time use 0.373s
# *** epoch7, train loss 0.0036, train rmse 67.6269, val loss 0.0036, val rmse 59.914477, time use 0.388s
# *** epoch8, train loss 0.0035, train rmse 66.4365, val loss 0.0034, val rmse 57.793457, time use 0.407s
# *** epoch9, train loss 0.0033, train rmse 65.1991, val loss 0.0033, val rmse 57.090895, time use 0.395s
# *** epoch10, train loss 0.0032, train rmse 63.9724, val loss 0.0032, val rmse 56.080416, time use 0.385s
# *** epoch11, train loss 0.0030, train rmse 62.3407, val loss 0.0030, val rmse 54.116213, time use 0.386s
# *** epoch12, train loss 0.0029, train rmse 60.9816, val loss 0.0029, val rmse 52.246288, time use 0.388s
# *** epoch13, train loss 0.0028, train rmse 59.4795, val loss 0.0028, val rmse 51.070137, time use 0.394s
# *** epoch14, train loss 0.0027, train rmse 58.0885, val loss 0.0027, val rmse 49.482371, time use 0.377s
# *** epoch15, train loss 0.0025, train rmse 56.1437, val loss 0.0026, val rmse 47.870057, time use 0.380s
# *** epoch16, train loss 0.0024, train rmse 54.9696, val loss 0.0025, val rmse 46.556670, time use 0.364s
# *** epoch17, train loss 0.0023, train rmse 53.3920, val loss 0.0024, val rmse 45.311851, time use 0.392s
# *** epoch18, train loss 0.0022, train rmse 52.3627, val loss 0.0023, val rmse 44.328452, time use 0.383s
# *** epoch19, train loss 0.0021, train rmse 51.5764, val loss 0.0023, val rmse 43.675888, time use 0.381s
# *** epoch20, train loss 0.0021, train rmse 51.1790, val loss 0.0023, val rmse 43.202731, time use 0.381s
# *** epoch21, train loss 0.0021, train rmse 50.8110, val loss 0.0022, val rmse 43.072898, time use 0.392s
# *** epoch22, train loss 0.0020, train rmse 50.5125, val loss 0.0022, val rmse 42.864401, time use 0.380s
# *** epoch23, train loss 0.0020, train rmse 50.2001, val loss 0.0022, val rmse 42.421000, time use 0.367s
# *** epoch24, train loss 0.0020, train rmse 49.9255, val loss 0.0022, val rmse 42.739400, time use 0.378s
# *** epoch25, train loss 0.0019, train rmse 49.3019, val loss 0.0022, val rmse 41.746431, time use 0.390s
# *** epoch26, train loss 0.0019, train rmse 49.1130, val loss 0.0021, val rmse 41.580596, time use 0.393s
# *** epoch27, train loss 0.0019, train rmse 48.9837, val loss 0.0022, val rmse 42.646240, time use 0.388s
# *** epoch28, train loss 0.0019, train rmse 48.5513, val loss 0.0021, val rmse 41.437397, time use 0.374s
# *** epoch29, train loss 0.0019, train rmse 48.5105, val loss 0.0021, val rmse 40.828570, time use 0.375s
# *** epoch30, train loss 0.0019, train rmse 48.2951, val loss 0.0021, val rmse 41.518302, time use 0.417s
# *** epoch31, train loss 0.0018, train rmse 48.0024, val loss 0.0021, val rmse 40.588689, time use 0.392s
# *** epoch32, train loss 0.0018, train rmse 47.8097, val loss 0.0021, val rmse 41.848921, time use 0.372s
# *** epoch33, train loss 0.0018, train rmse 47.5481, val loss 0.0020, val rmse 40.020129, time use 0.370s
# *** epoch34, train loss 0.0018, train rmse 47.7713, val loss 0.0020, val rmse 40.142633, time use 0.412s
# *** epoch35, train loss 0.0018, train rmse 47.4201, val loss 0.0020, val rmse 39.880796, time use 0.377s
# *** epoch36, train loss 0.0018, train rmse 47.0042, val loss 0.0020, val rmse 39.779224, time use 0.399s
# *** epoch37, train loss 0.0017, train rmse 46.8749, val loss 0.0019, val rmse 39.498982, time use 0.380s
# *** epoch38, train loss 0.0017, train rmse 46.8476, val loss 0.0019, val rmse 39.377623, time use 0.387s
# *** epoch39, train loss 0.0017, train rmse 46.6442, val loss 0.0019, val rmse 39.276385, time use 0.357s
# *** epoch40, train loss 0.0017, train rmse 46.6736, val loss 0.0019, val rmse 39.087391, time use 0.368s
# *** epoch41, train loss 0.0017, train rmse 46.5323, val loss 0.0019, val rmse 39.313846, time use 0.368s
# *** epoch42, train loss 0.0017, train rmse 46.4573, val loss 0.0019, val rmse 38.925269, time use 0.384s
# *** epoch43, train loss 0.0017, train rmse 46.6105, val loss 0.0019, val rmse 38.964636, time use 0.440s
# *** epoch44, train loss 0.0017, train rmse 46.1337, val loss 0.0019, val rmse 40.106256, time use 0.378s
# *** epoch45, train loss 0.0017, train rmse 46.2355, val loss 0.0019, val rmse 39.854822, time use 0.385s
# *** epoch46, train loss 0.0017, train rmse 46.1790, val loss 0.0019, val rmse 38.604933, time use 0.395s
# *** epoch47, train loss 0.0017, train rmse 45.8639, val loss 0.0019, val rmse 39.928915, time use 0.379s
# *** epoch48, train loss 0.0017, train rmse 45.9335, val loss 0.0018, val rmse 38.508539, time use 0.377s
# *** epoch49, train loss 0.0017, train rmse 45.9054, val loss 0.0018, val rmse 38.743223, time use 0.383s
# *** epoch50, train loss 0.0017, train rmse 46.1190, val loss 0.0018, val rmse 38.360259, time use 0.376s
# *** epoch51, train loss 0.0017, train rmse 45.9848, val loss 0.0019, val rmse 40.439213, time use 0.376s
# *** epoch52, train loss 0.0017, train rmse 45.8378, val loss 0.0019, val rmse 40.667611, time use 0.394s
# *** epoch53, train loss 0.0017, train rmse 45.9634, val loss 0.0019, val rmse 39.773031, time use 0.384s
# *** epoch54, train loss 0.0017, train rmse 45.7185, val loss 0.0018, val rmse 38.132214, time use 0.490s
# *** epoch55, train loss 0.0017, train rmse 45.8618, val loss 0.0018, val rmse 39.429974, time use 0.399s
# *** epoch56, train loss 0.0016, train rmse 45.4910, val loss 0.0018, val rmse 38.193015, time use 0.414s
# *** epoch57, train loss 0.0016, train rmse 45.6583, val loss 0.0018, val rmse 38.811347, time use 0.436s
# *** epoch58, train loss 0.0016, train rmse 45.5628, val loss 0.0018, val rmse 37.972748, time use 0.422s
# *** epoch59, train loss 0.0016, train rmse 45.5854, val loss 0.0018, val rmse 37.994509, time use 0.388s
# *** epoch60, train loss 0.0016, train rmse 45.4907, val loss 0.0018, val rmse 37.993385, time use 0.404s
# *** epoch61, train loss 0.0016, train rmse 45.2154, val loss 0.0018, val rmse 37.911871, time use 0.417s
# *** epoch62, train loss 0.0016, train rmse 45.3932, val loss 0.0018, val rmse 38.273312, time use 0.412s
# *** epoch63, train loss 0.0016, train rmse 45.3051, val loss 0.0018, val rmse 38.349776, time use 0.404s
# *** epoch64, train loss 0.0016, train rmse 45.4192, val loss 0.0018, val rmse 39.558063, time use 0.404s
# *** epoch65, train loss 0.0016, train rmse 45.3178, val loss 0.0018, val rmse 37.830365, time use 0.413s
# *** epoch66, train loss 0.0016, train rmse 45.1700, val loss 0.0018, val rmse 37.899744, time use 0.422s
# *** epoch67, train loss 0.0016, train rmse 45.1878, val loss 0.0018, val rmse 37.693547, time use 0.421s
# *** epoch68, train loss 0.0016, train rmse 45.4133, val loss 0.0018, val rmse 38.816415, time use 0.428s
# *** epoch69, train loss 0.0016, train rmse 45.2340, val loss 0.0018, val rmse 37.932395, time use 0.435s
# *** epoch70, train loss 0.0016, train rmse 45.2599, val loss 0.0018, val rmse 37.705983, time use 0.418s
# *** epoch71, train loss 0.0016, train rmse 45.1924, val loss 0.0018, val rmse 38.216146, time use 0.421s
# *** epoch72, train loss 0.0016, train rmse 45.2733, val loss 0.0018, val rmse 37.878377, time use 0.403s
# *** epoch73, train loss 0.0016, train rmse 44.8549, val loss 0.0018, val rmse 38.033742, time use 0.411s
# *** epoch74, train loss 0.0016, train rmse 45.3118, val loss 0.0018, val rmse 38.882524, time use 0.402s
# *** epoch75, train loss 0.0016, train rmse 45.1158, val loss 0.0017, val rmse 37.374366, time use 0.410s
# *** epoch76, train loss 0.0016, train rmse 45.1958, val loss 0.0017, val rmse 37.385107, time use 0.398s
# *** epoch77, train loss 0.0016, train rmse 45.2019, val loss 0.0017, val rmse 37.290662, time use 0.415s
# *** epoch78, train loss 0.0016, train rmse 44.9121, val loss 0.0018, val rmse 38.327946, time use 0.404s
# *** epoch79, train loss 0.0016, train rmse 45.0105, val loss 0.0017, val rmse 37.490376, time use 0.432s
# *** epoch80, train loss 0.0016, train rmse 45.1255, val loss 0.0018, val rmse 38.045916, time use 0.411s
#
# ****************************************
# Final result:
# Get best validation rmse 37.2907 at epoch 76
# Total time 31.70s
#
# Test result:
# Test RMSE: 36.85707861562233    Test MAE: 25.956943416595458    Test MAPE: 8.220469252291052

# %%
visualize(stop_epoch, train_loss_lst, val_loss_lst, y_label='Loss')
plot_metric(train_score_lst)
