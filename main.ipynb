# %% [markdown]
# # 循环神经网络
#
# ## 动手实现循环神经网络

# %%
import math
import torch
from torch import nn
import numpy as np
from datasets import *

# %% [markdown]
# 观察RNN的计算公式：
# $$h_t=\sigma (W_h x_t+U_h h_{t-1} + b_h),\ y_t=\sigma (W_y h_t+b_y)$$
# 其中$x_t$是t步的输入；$h_t$是t步的隐藏状态，需要我们初始化，并在每步间循环更新；$W_h,W_y,b_h,b_y$则是可学习参数；$\sigma$是激活函数，计算新的隐藏状态时一般使用Tanh，计算状态时需要考虑我们期望的输出的范围。例如，希望输出为非负，则使用ReLU。
#
# 为了方便管理，我们将所有参数和计算过程集中在一个类中。

# %%
class MyRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        """
        :param input_size: 指定输入数据的维度。例如，对于简单的时间序列预测问题，每一步的输入均为一个采样值，因此input_size=1.
        :param hidden_size: 指定隐藏状态的维度。这个值并不受输入和输出控制，但会影响模型的容量。
        :param output_size: 指定输出数据的维度。此值取决于具体的预测要求。例如，对简单的时间序列预测问题，output_size=1.
        """
        super().__init__()
        self.hidden_size = hidden_size
        
        # 可学习参数的维度设置，可以类比一下全连接网络的实现。其维度取决于输入数据的维度，以及指定的隐藏状态维度。
        self.w_h = nn.Parameter(torch.rand(input_size, hidden_size))
        self.u_h = nn.Parameter(torch.rand(hidden_size, hidden_size))
        self.b_h = nn.Parameter(torch.zeros(hidden_size))
        
        self.w_y = nn.Parameter(torch.rand(hidden_size, output_size))
        self.b_y = nn.Parameter(torch.zeros(output_size))
        
        # 准备激活函数。Dropout函数可选。
        self.tanh = nn.Tanh()
        self.leaky_relu = nn.LeakyReLU()
        
        # 可选：使用性能更好的参数初始化函数
        for param in self.parameters():
            if param.dim() > 1:
                nn.init.xavier_uniform_(param)
                
    def forward(self, x):
        """
        :param x: 输入序列。一般来说，此输入包含三个维度：batch，序列长度，以及每条数据的特征。
        """
        batch_size = x.size(0)
        seq_len = x.size(1)
        
        # 初始化隐藏状态，一般设为全0。由于是内部新建的变量，需要同步设备位置。
        h = torch.zeros(batch_size, self.hidden_size).to(x.device)
        # RNN实际上只能一步一步处理序列。因此需要用循环迭代。
        y_list = []
        for i in range(seq_len):
            h = self.tanh(torch.matmul(x[:, i, :], self.w_h) + 
                             torch.matmul(h, self.u_h) + self.b_h)  # (batch_size, hidden_size)
            y = self.leaky_relu(torch.matmul(h, self.w_y) + self.b_y)  # (batch_size, output_size)
            y_list.append(y)
        # 一般来说，RNN的返回值为最后一步的隐藏状态，以及每一步的输出状态。
        return torch.stack(y_list, dim=1), h

# %% [markdown]
# 使用随机生成的数据进行简单的测试：

# %%
device = 'cpu'  # 如果电脑上无Nvidia显卡或未安装CUDA框架，请更改为 'cpu'
batch_size = 64
seq_len = 12
input_size = 2
hidden_size = 32
output_size = 1

x = torch.rand(batch_size, seq_len, input_size).to(device)
rnn = MyRNN(input_size, hidden_size, output_size).to(device)
hidden, y = rnn(x)
print(hidden.shape, y.shape)
# Out:
# torch.Size([64, 12, 1]) torch.Size([64, 32])

# %% [markdown]
# ## 使用RNN进行实验
#
# 结合上一章的数据处理方式，首先将原始数据处理为短序列，随后以batch的形式进行训练，并在测试集上计算结果。
#
# ### 数据处理

# %%
# 读取数据
KrakowData = KrakowDataset()
data_df = KrakowData.data
data_df.head()
# Out:
#                      171_temperature  171_humidity  171_pressure   171_pm1  \
# 2017-01-01 00:00:00         0.254545      0.082803      0.731568  0.639130
# 2017-01-01 01:00:00         0.236364      0.082803      0.722620  0.560870
# 2017-01-01 02:00:00         0.254545      0.082803      0.708840  0.582609
# 2017-01-01 03:00:00         0.236364      0.082803      0.699893  0.626087
# 2017-01-01 04:00:00         0.236364      0.082803      0.691303  0.595652
#
#                      171_pm25  171_pm10
# 2017-01-01 00:00:00  0.592334  0.567627
# 2017-01-01 01:00:00  0.522648  0.505543
# 2017-01-01 02:00:00  0.547038  0.532151
# 2017-01-01 03:00:00  0.595819  0.578714
# 2017-01-01 04:00:00  0.564460  0.549889

# %% [markdown]
# 我们使用预先定义的数据对象读取数据并预处理

# %% [markdown]
# 之后调用数据集构造函数将处理后的数据封装为torch.utils.data.Dataset数据集，并构造dataloader

# %%
KrakowData = KrakowDataset()
train_set, val_set, test_set = KrakowData.construct_set(0.6, 0.2)

batch_size = 64
train_loader = data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
val_loader = data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)
test_loader = data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)
train_loader

# %% [markdown]
# 为了保证模型能够正常训练，模型的输入需要进行归一化。我们已经在KrakowDataset的初始化过程中进行了归一化。
#
# 在测试模型时，需要将数据反归一化以得到正常的测试结果。

# %% [markdown]
# ### 模型初始化
#
# 为了能够实现可学习参数的更新，我们还需要提供合理的损失函数和优化器。
#
# 损失函数应当按照具体任务选择，对于我们这里的回归问题，一般使用MSELoss。
#
# 优化器可以从torch.optim中选择。我们这里选择Adam优化器。优化器初始化时，需要提供所有需要优化的参数。由于我们将模型放入了一个nn.Module的子类中，直接使用model.parameters()就可以得到所有参数。

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size = train_set.X.shape[-1]
hidden_size = 64
output_size = 1
print(input_size, hidden_size, output_size)
seq_len = 12
lr = 0.0001
epochs = 80
loss_func = nn.MSELoss()

my_rnn = MyRNN(input_size, hidden_size, output_size).to(device)

optimizer = torch.optim.Adam(my_rnn.parameters(), lr)
# Out:
# 6 64 1

# %% [markdown]
# > 顺便一说，如果需要同时优化多个模型的参数，使用下面的语句即可：
#
#     model_a = MyRNN(input_size=1, hidden_size=32, output_size=1).to(device)
#     model_b = MyRNN(input_size=1, hidden_size=32, output_size=1).to(device)
#     optimizer = torch.optim.Adam(list(model_a.parameters()) + list(model_b.parameters())
#
# > 这是因为model.parameters()是一个生成器，因此可以用list()得到所有参数的列表，然后用相加操作即可。

# %% [markdown]
# 为了能够测试模型的预测性能，也需要选择一个或多个测试指标。指标的选择取决于具体任务。对于回归任务，一般使用RMSE、MAE和MAPE。
#
# Scikit-learn中提供了MAE和MSE。RMSE可以通过再MSE上求根得到，MAPE则需要自己实现。

# %%
from sklearn.metrics import mean_squared_error as mse, mean_absolute_error as mae

def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_index = (y_true > 0)
    y_true = y_true[non_zero_index]
    y_pred = y_pred[non_zero_index]

    mape = np.abs((y_true - y_pred) / y_true)
    mape[np.isinf(mape)] = 0
    return np.mean(mape) * 100

# %% [markdown]
# **在附带代码utils.py中已封装三种常用测试指标函数，可以直接使用**

# %% [markdown]
# ### 进行训练

# %% [markdown]
# 对于RNN的输出如何处理，也取决于具体的任务和模型设计。这里我们直接将RNN输出状态的最后一步作为对下一消失温度的预测，因为最后一步输出理论上包含了整个输入历史序列的信息。

# %% [markdown]
# **在utils.py脚本中同样封装了训练函数，可接收多种参数，可自行选用功能**

# %%
from utils import *

train_loss_lst, val_loss_lst, \
    train_score_lst, val_score_lst, stop_epoch = train(my_rnn, train_loader, val_loader, test_loader,
                                                       loss_func, KrakowData.denormalize, optimizer, epochs,
                                                       early_stop=20, device=device, output_model=None)
# Out:
# *** epoch1, train loss 0.0213, train rmse 39.9255, val loss 0.0027, val rmse 14.344775, time use 0.281s
# *** epoch2, train loss 0.0075, train rmse 24.3786, val loss 0.0022, val rmse 12.422585, time use 0.313s
# *** epoch3, train loss 0.0053, train rmse 20.4633, val loss 0.0013, val rmse 9.883302, time use 0.281s
# *** epoch4, train loss 0.0039, train rmse 17.5082, val loss 0.0012, val rmse 9.454305, time use 0.312s
# *** epoch5, train loss 0.0030, train rmse 15.4775, val loss 0.0007, val rmse 7.457576, time use 0.375s
# *** epoch6, train loss 0.0025, train rmse 13.9794, val loss 0.0005, val rmse 5.997146, time use 0.266s
# *** epoch7, train loss 0.0022, train rmse 12.9992, val loss 0.0004, val rmse 5.516191, time use 0.297s
# *** epoch8, train loss 0.0020, train rmse 12.5153, val loss 0.0004, val rmse 5.200453, time use 0.219s
# *** epoch9, train loss 0.0018, train rmse 11.8889, val loss 0.0004, val rmse 5.231228, time use 0.281s
# *** epoch10, train loss 0.0017, train rmse 11.4147, val loss 0.0003, val rmse 4.858754, time use 0.250s
# *** epoch11, train loss 0.0016, train rmse 11.1628, val loss 0.0004, val rmse 5.761282, time use 0.234s
# *** epoch12, train loss 0.0015, train rmse 10.7349, val loss 0.0005, val rmse 5.980284, time use 0.281s
# *** epoch13, train loss 0.0014, train rmse 10.5645, val loss 0.0003, val rmse 4.441542, time use 0.328s
# *** epoch14, train loss 0.0014, train rmse 10.3629, val loss 0.0002, val rmse 4.250670, time use 0.282s
# *** epoch15, train loss 0.0013, train rmse 10.1276, val loss 0.0002, val rmse 4.312257, time use 0.312s
# *** epoch16, train loss 0.0013, train rmse 9.8883, val loss 0.0003, val rmse 4.574103, time use 0.266s
# *** epoch17, train loss 0.0013, train rmse 9.8254, val loss 0.0002, val rmse 4.096114, time use 0.281s
# *** epoch18, train loss 0.0012, train rmse 9.6223, val loss 0.0002, val rmse 4.067919, time use 0.266s
# *** epoch19, train loss 0.0011, train rmse 9.3942, val loss 0.0002, val rmse 3.817041, time use 0.344s
# *** epoch20, train loss 0.0011, train rmse 9.3985, val loss 0.0002, val rmse 4.048948, time use 0.234s
# *** epoch21, train loss 0.0011, train rmse 9.4064, val loss 0.0002, val rmse 3.745686, time use 0.328s
# *** epoch22, train loss 0.0011, train rmse 9.2227, val loss 0.0002, val rmse 4.302636, time use 0.299s
# *** epoch23, train loss 0.0011, train rmse 9.1426, val loss 0.0002, val rmse 3.873423, time use 0.281s
# *** epoch24, train loss 0.0011, train rmse 9.0144, val loss 0.0002, val rmse 4.050652, time use 0.297s
# *** epoch25, train loss 0.0010, train rmse 8.9745, val loss 0.0002, val rmse 3.742049, time use 0.250s
# *** epoch26, train loss 0.0010, train rmse 8.8791, val loss 0.0001, val rmse 3.394780, time use 0.266s
# *** epoch27, train loss 0.0010, train rmse 8.8524, val loss 0.0002, val rmse 3.705440, time use 0.313s
# *** epoch28, train loss 0.0010, train rmse 8.7978, val loss 0.0002, val rmse 4.105349, time use 0.281s
# *** epoch29, train loss 0.0010, train rmse 8.7184, val loss 0.0001, val rmse 3.287112, time use 0.358s
# *** epoch30, train loss 0.0010, train rmse 8.5940, val loss 0.0002, val rmse 4.108473, time use 0.366s
# *** epoch31, train loss 0.0010, train rmse 8.5827, val loss 0.0002, val rmse 3.505794, time use 0.281s
# *** epoch32, train loss 0.0010, train rmse 8.6136, val loss 0.0002, val rmse 3.511045, time use 0.281s
# *** epoch33, train loss 0.0010, train rmse 8.6370, val loss 0.0001, val rmse 3.234454, time use 0.328s
# *** epoch34, train loss 0.0009, train rmse 8.5053, val loss 0.0001, val rmse 3.315017, time use 0.344s
# *** epoch35, train loss 0.0009, train rmse 8.4219, val loss 0.0002, val rmse 3.466093, time use 0.297s
# *** epoch36, train loss 0.0009, train rmse 8.4881, val loss 0.0001, val rmse 3.162860, time use 0.344s
# *** epoch37, train loss 0.0009, train rmse 8.4044, val loss 0.0001, val rmse 3.138163, time use 0.329s
# *** epoch38, train loss 0.0009, train rmse 8.5056, val loss 0.0001, val rmse 3.035372, time use 0.297s
# *** epoch39, train loss 0.0009, train rmse 8.1932, val loss 0.0001, val rmse 3.042983, time use 0.312s
# *** epoch40, train loss 0.0009, train rmse 8.2467, val loss 0.0002, val rmse 3.850507, time use 0.313s
# *** epoch41, train loss 0.0009, train rmse 8.2506, val loss 0.0002, val rmse 3.556414, time use 0.313s
# *** epoch42, train loss 0.0009, train rmse 8.2897, val loss 0.0003, val rmse 4.492063, time use 0.266s
# *** epoch43, train loss 0.0009, train rmse 8.2994, val loss 0.0001, val rmse 3.288708, time use 0.328s
# *** epoch44, train loss 0.0009, train rmse 8.1799, val loss 0.0002, val rmse 3.475540, time use 0.375s
# *** epoch45, train loss 0.0009, train rmse 8.2353, val loss 0.0001, val rmse 3.267024, time use 0.312s
# *** epoch46, train loss 0.0009, train rmse 8.2710, val loss 0.0001, val rmse 2.943659, time use 0.247s
# *** epoch47, train loss 0.0009, train rmse 8.5050, val loss 0.0001, val rmse 2.963064, time use 0.344s
# *** epoch48, train loss 0.0009, train rmse 8.1788, val loss 0.0001, val rmse 3.014212, time use 0.313s
# *** epoch49, train loss 0.0009, train rmse 8.2567, val loss 0.0001, val rmse 2.955061, time use 0.266s
# *** epoch50, train loss 0.0009, train rmse 8.1043, val loss 0.0001, val rmse 2.963741, time use 0.328s
# *** epoch51, train loss 0.0009, train rmse 8.0592, val loss 0.0001, val rmse 2.862157, time use 0.387s
# *** epoch52, train loss 0.0009, train rmse 8.1572, val loss 0.0001, val rmse 2.869664, time use 0.344s
# *** epoch53, train loss 0.0009, train rmse 8.2596, val loss 0.0001, val rmse 2.909980, time use 0.359s
# *** epoch54, train loss 0.0009, train rmse 8.1856, val loss 0.0001, val rmse 3.263187, time use 0.328s
# *** epoch55, train loss 0.0009, train rmse 8.0540, val loss 0.0002, val rmse 3.468427, time use 0.375s
# *** epoch56, train loss 0.0008, train rmse 7.9892, val loss 0.0001, val rmse 2.870337, time use 0.391s
# *** epoch57, train loss 0.0009, train rmse 8.1097, val loss 0.0001, val rmse 3.094427, time use 0.453s
# *** epoch58, train loss 0.0009, train rmse 8.0872, val loss 0.0001, val rmse 3.003108, time use 0.328s
# *** epoch59, train loss 0.0009, train rmse 8.1014, val loss 0.0002, val rmse 3.902533, time use 0.375s
# *** epoch60, train loss 0.0008, train rmse 8.0677, val loss 0.0002, val rmse 3.458028, time use 0.344s
# *** epoch61, train loss 0.0008, train rmse 8.0197, val loss 0.0001, val rmse 3.032982, time use 0.359s
# *** epoch62, train loss 0.0009, train rmse 8.1174, val loss 0.0001, val rmse 3.379793, time use 0.391s
# *** epoch63, train loss 0.0008, train rmse 8.0802, val loss 0.0001, val rmse 3.186188, time use 0.375s
# *** epoch64, train loss 0.0008, train rmse 8.0565, val loss 0.0001, val rmse 3.260142, time use 0.359s
# *** epoch65, train loss 0.0008, train rmse 7.9715, val loss 0.0002, val rmse 3.615917, time use 0.344s
# *** epoch66, train loss 0.0009, train rmse 8.1842, val loss 0.0001, val rmse 2.978753, time use 0.297s
# *** epoch67, train loss 0.0008, train rmse 7.9876, val loss 0.0002, val rmse 3.836943, time use 0.329s
# *** epoch68, train loss 0.0009, train rmse 8.0549, val loss 0.0002, val rmse 3.741366, time use 0.344s
# *** epoch69, train loss 0.0008, train rmse 8.0399, val loss 0.0001, val rmse 2.804061, time use 0.313s
# *** epoch70, train loss 0.0008, train rmse 8.0285, val loss 0.0001, val rmse 3.119222, time use 0.328s
# *** epoch71, train loss 0.0008, train rmse 8.0120, val loss 0.0001, val rmse 2.837313, time use 0.359s
# *** epoch72, train loss 0.0008, train rmse 8.0122, val loss 0.0001, val rmse 2.822881, time use 0.422s
# *** epoch73, train loss 0.0008, train rmse 7.9625, val loss 0.0001, val rmse 2.791218, time use 0.359s
# *** epoch74, train loss 0.0008, train rmse 7.9940, val loss 0.0001, val rmse 2.970650, time use 0.375s
# *** epoch75, train loss 0.0009, train rmse 8.0959, val loss 0.0001, val rmse 2.867625, time use 0.359s
# *** epoch76, train loss 0.0008, train rmse 8.0047, val loss 0.0001, val rmse 2.795617, time use 0.359s
# *** epoch77, train loss 0.0008, train rmse 7.9793, val loss 0.0001, val rmse 2.996965, time use 0.344s
# *** epoch78, train loss 0.0008, train rmse 7.9662, val loss 0.0001, val rmse 2.829845, time use 0.422s
# *** epoch79, train loss 0.0008, train rmse 7.9709, val loss 0.0001, val rmse 3.021421, time use 0.375s
# *** epoch80, train loss 0.0008, train rmse 7.9188, val loss 0.0001, val rmse 2.770109, time use 0.409s
#
# ****************************************
# Final result:
# Get best validation rmse 2.7701 at epoch 79
# Total time 25.86s
#
# Test result:
# Test RMSE: 6.997160403221489    Test MAE: 4.7553394849483785    Test MAPE: 18.94794054902517

# %% [markdown]
# ### 可视化训练结果

# %%
visualize(stop_epoch, train_loss_lst, val_loss_lst, y_label='Loss')
plot_metric(train_score_lst)

# %% [markdown]
# ## PyTorch封装RNN介绍
#
# PyTorch中已经封装了一个可开箱即用的RNN模型，并且相比起我们的版本，其对RNN的实现更加完整，其中包括：
#
# - 多层RNN
# - 双向RNN
#
# nn.RNN的使用方式很简单，其接口与我们的版本主要区别在于：
#
# - 多了两个参数num_layers和bidirectional，分别用于实现多层RNN和双向RNN；
# - 包含参数batch_first，控制输入的格式，下面会进一步解释；
# - 并没有output_size参数，下面会进一步解释。
#
# 例如初始化一个4层，双向的RNN可以用一下语句：

# %%
bi_rnn = nn.RNN(input_size=2, hidden_size=64, num_layers=1, bidirectional=True, batch_first=True)

# %% [markdown]
# 其使用方法与我们的版本也稍有区别，主要包括：
#
# - 默认状态下，输入的格式不是(batch_size, seq_len, input_size)而是(seq_len, batch_size, input_size)。batch_size维度是否在第一维由参数batch_first控制。
# - 内部实现并没有输出层，因此虽然输出仍然为(output, hidden)，但output实际上就是每一步的隐藏状态。需要我们自己再实现一个输出层。
#     - 输出的hidden的格式为(num_layers * num_direction, batch_size, hidden_size)。其格式不受batch_first控制。
#     - output的格式与输入是一致的，即默认状态下为(seq_len, batch_size, hidden_size)。
#
# 使用随机生成的数据进行测试：

# %%
device = 'cpu'
batch_size = 32
seq_len = 12
input_size = 2

x = torch.randn(batch_size, seq_len, input_size).to(device)
bi_rnn = bi_rnn.to(device)
output, hidden = bi_rnn(x)
print(output.shape, hidden.shape)
# Out:
# torch.Size([32, 12, 128]) torch.Size([2, 32, 64])

# %% [markdown]
# ### 使用封装的RNN进行实验

# %%
from utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size = train_set.X.shape[-1]
hidden_size = 64
output_size = 1
seq_len = 12
lr = 0.0001
epochs = 80
loss_func = nn.MSELoss()

nn_rnn = nn.RNN(input_size=input_size, hidden_size=hidden_size, num_layers=1, batch_first=True).to(device)
out_linear = nn.Sequential(nn.Linear(hidden_size, 1),
                           nn.LeakyReLU()).to(device)

optimizer = torch.optim.Adam(list(nn_rnn.parameters()) + list(out_linear.parameters()), lr)

train_loss_lst, val_loss_lst, \
    train_score_lst, val_score_lst, stop_epoch = train(nn_rnn, train_loader, val_loader, test_loader,
                                                       loss_func, KrakowData.denormalize, optimizer, epochs,
                                                       early_stop=20, device=device, output_model=out_linear)
# Out:
# *** epoch1, train loss 0.0179, train rmse 37.3166, val loss 0.0019, val rmse 12.227280, time use 0.250s
# *** epoch2, train loss 0.0067, train rmse 22.6833, val loss 0.0006, val rmse 6.450660, time use 0.219s
# *** epoch3, train loss 0.0038, train rmse 17.3813, val loss 0.0004, val rmse 5.488265, time use 0.234s
# *** epoch4, train loss 0.0032, train rmse 15.9212, val loss 0.0005, val rmse 6.081074, time use 0.281s
# *** epoch5, train loss 0.0028, train rmse 14.8365, val loss 0.0003, val rmse 4.348026, time use 0.266s
# *** epoch6, train loss 0.0025, train rmse 13.9444, val loss 0.0002, val rmse 4.333249, time use 0.235s
# *** epoch7, train loss 0.0023, train rmse 13.3061, val loss 0.0002, val rmse 4.267731, time use 0.234s
# *** epoch8, train loss 0.0021, train rmse 12.8389, val loss 0.0002, val rmse 3.908527, time use 0.281s
# *** epoch9, train loss 0.0020, train rmse 12.4444, val loss 0.0002, val rmse 3.864013, time use 0.250s
# *** epoch10, train loss 0.0019, train rmse 12.0658, val loss 0.0002, val rmse 3.686726, time use 0.234s
# *** epoch11, train loss 0.0018, train rmse 11.7509, val loss 0.0003, val rmse 4.495484, time use 0.312s
# *** epoch12, train loss 0.0017, train rmse 11.4716, val loss 0.0002, val rmse 3.673193, time use 0.234s
# *** epoch13, train loss 0.0016, train rmse 11.1195, val loss 0.0002, val rmse 3.562441, time use 0.250s
# *** epoch14, train loss 0.0016, train rmse 11.0353, val loss 0.0002, val rmse 3.525407, time use 0.234s
# *** epoch15, train loss 0.0015, train rmse 10.7390, val loss 0.0002, val rmse 3.501985, time use 0.266s
# *** epoch16, train loss 0.0015, train rmse 10.6206, val loss 0.0002, val rmse 3.412000, time use 0.266s
# *** epoch17, train loss 0.0014, train rmse 10.4850, val loss 0.0002, val rmse 3.845511, time use 0.219s
# *** epoch18, train loss 0.0014, train rmse 10.2593, val loss 0.0002, val rmse 3.407329, time use 0.203s
# *** epoch19, train loss 0.0013, train rmse 10.1250, val loss 0.0001, val rmse 3.355327, time use 0.219s
# *** epoch20, train loss 0.0013, train rmse 10.0087, val loss 0.0001, val rmse 3.266092, time use 0.297s
# *** epoch21, train loss 0.0013, train rmse 9.8811, val loss 0.0002, val rmse 3.423510, time use 0.264s
# *** epoch22, train loss 0.0012, train rmse 9.6897, val loss 0.0001, val rmse 3.246566, time use 0.281s
# *** epoch23, train loss 0.0012, train rmse 9.5797, val loss 0.0002, val rmse 3.420958, time use 0.281s
# *** epoch24, train loss 0.0012, train rmse 9.5080, val loss 0.0001, val rmse 3.328088, time use 0.234s
# *** epoch25, train loss 0.0012, train rmse 9.4185, val loss 0.0001, val rmse 3.382661, time use 0.281s
# *** epoch26, train loss 0.0012, train rmse 9.3267, val loss 0.0002, val rmse 3.457217, time use 0.266s
# *** epoch27, train loss 0.0011, train rmse 9.3125, val loss 0.0001, val rmse 3.200753, time use 0.250s
# *** epoch28, train loss 0.0011, train rmse 9.1652, val loss 0.0001, val rmse 3.275984, time use 0.266s
# *** epoch29, train loss 0.0011, train rmse 9.0895, val loss 0.0001, val rmse 3.165919, time use 0.250s
# *** epoch30, train loss 0.0011, train rmse 8.9923, val loss 0.0001, val rmse 3.306591, time use 0.297s
# *** epoch31, train loss 0.0011, train rmse 8.9937, val loss 0.0001, val rmse 3.201965, time use 0.234s
# *** epoch32, train loss 0.0010, train rmse 8.8974, val loss 0.0001, val rmse 3.153208, time use 0.234s
# *** epoch33, train loss 0.0010, train rmse 8.8032, val loss 0.0001, val rmse 3.117587, time use 0.266s
# *** epoch34, train loss 0.0010, train rmse 8.7873, val loss 0.0001, val rmse 3.086873, time use 0.266s
# *** epoch35, train loss 0.0010, train rmse 8.6836, val loss 0.0001, val rmse 3.198190, time use 0.250s
# *** epoch36, train loss 0.0010, train rmse 8.6876, val loss 0.0001, val rmse 3.091162, time use 0.219s
# *** epoch37, train loss 0.0010, train rmse 8.5639, val loss 0.0001, val rmse 3.239312, time use 0.250s
# *** epoch38, train loss 0.0010, train rmse 8.5943, val loss 0.0001, val rmse 3.263991, time use 0.219s
# *** epoch39, train loss 0.0010, train rmse 8.5813, val loss 0.0001, val rmse 3.049176, time use 0.281s
# *** epoch40, train loss 0.0009, train rmse 8.4262, val loss 0.0001, val rmse 3.239737, time use 0.266s
# *** epoch41, train loss 0.0009, train rmse 8.4570, val loss 0.0001, val rmse 3.084993, time use 0.297s
# *** epoch42, train loss 0.0009, train rmse 8.4616, val loss 0.0001, val rmse 3.007391, time use 0.250s
# *** epoch43, train loss 0.0009, train rmse 8.3821, val loss 0.0001, val rmse 2.958810, time use 0.266s
# *** epoch44, train loss 0.0009, train rmse 8.3383, val loss 0.0001, val rmse 3.007879, time use 0.250s
# *** epoch45, train loss 0.0009, train rmse 8.2834, val loss 0.0001, val rmse 3.002817, time use 0.359s
# *** epoch46, train loss 0.0009, train rmse 8.3291, val loss 0.0001, val rmse 3.076578, time use 0.344s
# *** epoch47, train loss 0.0009, train rmse 8.2958, val loss 0.0001, val rmse 2.977017, time use 0.297s
# *** epoch48, train loss 0.0009, train rmse 8.1628, val loss 0.0001, val rmse 3.026300, time use 0.319s
# *** epoch49, train loss 0.0009, train rmse 8.2200, val loss 0.0001, val rmse 2.976263, time use 0.297s
# *** epoch50, train loss 0.0009, train rmse 8.1663, val loss 0.0001, val rmse 3.291065, time use 0.234s
# *** epoch51, train loss 0.0009, train rmse 8.1093, val loss 0.0001, val rmse 3.088470, time use 0.250s
# *** epoch52, train loss 0.0009, train rmse 8.0681, val loss 0.0001, val rmse 3.092951, time use 0.266s
# *** epoch53, train loss 0.0009, train rmse 8.1206, val loss 0.0001, val rmse 2.984115, time use 0.219s
# *** epoch54, train loss 0.0009, train rmse 8.1926, val loss 0.0001, val rmse 2.966684, time use 0.250s
# *** epoch55, train loss 0.0009, train rmse 8.0064, val loss 0.0001, val rmse 2.985505, time use 0.219s
# *** epoch56, train loss 0.0008, train rmse 8.0178, val loss 0.0001, val rmse 3.111771, time use 0.297s
# *** epoch57, train loss 0.0008, train rmse 8.0147, val loss 0.0001, val rmse 2.947386, time use 0.234s
# *** epoch58, train loss 0.0008, train rmse 8.0195, val loss 0.0001, val rmse 2.949790, time use 0.245s
# *** epoch59, train loss 0.0008, train rmse 7.9975, val loss 0.0001, val rmse 2.914999, time use 0.272s
# *** epoch60, train loss 0.0009, train rmse 8.1144, val loss 0.0001, val rmse 3.078779, time use 0.250s
# *** epoch61, train loss 0.0008, train rmse 7.9385, val loss 0.0001, val rmse 3.031112, time use 0.266s
# *** epoch62, train loss 0.0008, train rmse 7.9520, val loss 0.0001, val rmse 3.016396, time use 0.266s
# *** epoch63, train loss 0.0008, train rmse 8.0010, val loss 0.0001, val rmse 2.875349, time use 0.344s
# *** epoch64, train loss 0.0008, train rmse 8.0170, val loss 0.0001, val rmse 3.265474, time use 0.312s
# *** epoch65, train loss 0.0008, train rmse 7.9063, val loss 0.0001, val rmse 2.966423, time use 0.328s
# *** epoch66, train loss 0.0008, train rmse 7.9417, val loss 0.0001, val rmse 3.202533, time use 0.281s
# *** epoch67, train loss 0.0008, train rmse 8.0498, val loss 0.0001, val rmse 3.214215, time use 0.266s
# *** epoch68, train loss 0.0008, train rmse 7.9456, val loss 0.0001, val rmse 2.879273, time use 0.297s
# *** epoch69, train loss 0.0008, train rmse 8.0203, val loss 0.0001, val rmse 2.906270, time use 0.281s
# *** epoch70, train loss 0.0008, train rmse 7.9539, val loss 0.0001, val rmse 2.919926, time use 0.281s
# *** epoch71, train loss 0.0008, train rmse 7.9317, val loss 0.0001, val rmse 2.983463, time use 0.297s
# *** epoch72, train loss 0.0008, train rmse 8.0184, val loss 0.0001, val rmse 2.951454, time use 0.281s
# *** epoch73, train loss 0.0008, train rmse 7.9836, val loss 0.0001, val rmse 3.171476, time use 0.281s
# *** epoch74, train loss 0.0008, train rmse 8.0302, val loss 0.0001, val rmse 3.172436, time use 0.313s
# *** epoch75, train loss 0.0008, train rmse 7.9959, val loss 0.0001, val rmse 2.988694, time use 0.293s
# *** epoch76, train loss 0.0008, train rmse 7.9521, val loss 0.0001, val rmse 3.051742, time use 0.266s
# *** epoch77, train loss 0.0008, train rmse 8.0038, val loss 0.0001, val rmse 2.933222, time use 0.344s
# *** epoch78, train loss 0.0008, train rmse 7.9665, val loss 0.0001, val rmse 3.067010, time use 0.375s
# *** epoch79, train loss 0.0008, train rmse 7.9637, val loss 0.0001, val rmse 3.033106, time use 0.359s
# *** epoch80, train loss 0.0008, train rmse 7.9820, val loss 0.0001, val rmse 3.035707, time use 0.297s
#
# ****************************************
# Final result:
# Get best validation rmse 2.8753 at epoch 62
# Total time 21.58s
#
# Test result:
# Test RMSE: 7.021688249655824    Test MAE: 4.782195513065044    Test MAPE: 19.039854378654407

# %%
visualize(stop_epoch, train_loss_lst, val_loss_lst, y_label='Loss')
plot_metric(train_score_lst)

# %% [markdown]
# ## LSTM手动实现

# %%
class My_legacyLSTM(nn.Module):
    def _init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.w_f = nn.Parameter(torch.rand(input_size, hidden_size))
        self.u_f = nn.Parameter(torch.rand(hidden_size, hidden_size))
        self.b_f = nn.Parameter(torch.zeros(hidden_size))

        self.w_i = nn.Parameter(torch.rand(input_size, hidden_size))
        self.u_i = nn.Parameter(torch.rand(hidden_size, hidden_size))
        self.b_i = nn.Parameter(torch.zeros(hidden_size))

        self.w_o = nn.Parameter(torch.rand(input_size, hidden_size))
        self.u_o = nn.Parameter(torch.rand(hidden_size, hidden_size))
        self.b_o = nn.Parameter(torch.zeros(hidden_size))

        self.w_c = nn.Parameter(torch.rand(input_size, hidden_size))
        self.u_c = nn.Parameter(torch.rand(hidden_size, hidden_size))
        self.b_c = nn.Parameter(torch.zeros(hidden_size))

        self.sigmoid = nn.Sigmoid()
        self.tanh = nn.Tanh()
        for param in self.parameters():
            if param.dim() > 1:
                nn.init.xavier_uniform_(param)

    def forward(self, x):
        batch_size = x.size(0)
        seq_len = x.size(1)

        # 需要初始化隐藏状态和细胞状态
        h = torch.zeros(batch_size, self.hidden_size).to(x.device)
        c = torch.zeros(batch_size, self.hidden_size).to(x.device)
        y_list = []
        for i in range(seq_len):
            forget_gate = self.sigmoid(torch.matmul(x[:, i, :], self.w_f) +
                                       torch.matmul(h, self.u_f) + self.b_f)
            # (batch_siz,hidden_size)
            input_gate = self.sigmoid(torch.matmul(x[:, i, :], self.w_i) +
                                      torch.matmul(h, self.u_i) + self.b_i)
            output_gate = self.sigmoid(torch.matmul(x[:, i, :], self.w_o) +
                                       torch.matmul(h, self.u_o) + self.b_o)
            # 这里可以看到各个门的运作方式。
            # 三个门均通过hadamard积作用在每一个维度上。
            c = forget_gate * c + input_gate * self.tanh(torch.matmul(x[:, i, :], self.w_c) +
                                                         torch.matmul(h, self.u_c) + self.b_c)
            h = output_gate * self.tanh(c)
            y_list.append(h)
        return torch.stack(y_list, dim=1), (h, c)

# %%
class My_LSTM(nn. Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.gates = nn.Linear(input_size + hidden_size, hidden_size * 4)
        self.sigmoid = nn.Sigmoid()
        self.tanh = nn. Tanh()
        self.output = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.ReLU(),
            nn.Linear(hidden_size // 2, output_size)
        )
        for param in self.parameters():
            if param.dim() > 1:
                nn.init.xavier_uniform_(param)

    def forward(self, x):
        batch_size = x.size(0)
        seq_len = x.size(1)
        h, c = (torch.zeros(batch_size, self.hidden_size).to(x.device) for _ in range(2))
        y_list = []
        for i in range(seq_len):
            forget_gate, input_gate, output_gate, candidate_cell = \
                self.gates(torch.cat([x[:, i, :], h], dim=-1)).chunk(4, -1)
            forget_gate, input_gate, output_gate = (self.sigmoid(g)
                                                    for g in (forget_gate, input_gate, output_gate))
            c = forget_gate * c + input_gate * self.tanh(candidate_cell)
            h = output_gate * self.tanh(c)
            y_list.append(self.output(h))
        return torch.stack(y_list, dim=1), (h, c)

# %% [markdown]
# ## GRU手动实现

# %%
class My_GRU(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        
        self.gates = nn.Linear(input_size+hidden_size, hidden_size*2)
        # 用于计算candidate hidden state
        self.hidden_transform = nn.Linear(input_size+hidden_size, hidden_size)
        
        self.sigmoid = nn.Sigmoid()
        self.tanh = nn.Tanh()
        
        self.output = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.ReLU(),
            nn.Linear(hidden_size // 2, output_size)
        )
            
        for param in self.parameters():
            if param.dim() > 1:
                nn.init.xavier_uniform_(param)
                
    def forward(self, x):
        batch_size = x.size(0)
        seq_len = x.size(1)
        
        h = torch.zeros(batch_size, self.hidden_size).to(x.device)
        y_list = []
        for i in range(seq_len):
            update_gate, reset_gate = self.gates(torch.cat([x[:, i, :], h], dim=-1)).chunk(2, -1)
            update_gate, reset_gate = (self.sigmoid(gate) for gate in (update_gate, reset_gate))
            candidate_hidden = self.tanh(self.hidden_transform(torch.cat([x[:, i, :], reset_gate * h], dim=-1)))
            h = (1-update_gate) * h + update_gate * candidate_hidden
            y_list.append(self.output(h))
        return torch.stack(y_list, dim=1), h
